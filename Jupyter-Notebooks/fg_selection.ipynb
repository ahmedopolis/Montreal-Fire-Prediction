# %%
import os
import pandas as pd
import numpy as np
from numpy import where
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, auc, roc_auc_score, roc_curve, classification_report, cohen_kappa_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import permutation_importance

# %%
from sklearn.preprocessing import RobustScaler

# %%
from scipy.stats import f_oneway, chi2_contingency
from sklearn.feature_selection import mutual_info_classif

# %%
#df = pd.read_csv('df_fe_combined.csv')
df = pd.read_csv('Data/Processed_Datasets/Combined_tables/df_fe_combined.csv', index_col=0)

# Sort dataframe according to month and grid ID
df.sort_values(['MONTH', '1000_GRID_ID'])

# Reset the index without adding an index column
df.reset_index(drop=True, inplace=True)

# %%
df.describe(include='all')
# Out:
#         1000_GRID_ID    MONTH CODEMAMROT   CRIME_COUNT  \
# count          65688    65688      65688  65688.000000
# unique           714       92         34           NaN
# top     Fqp0-LorCOE=  2016-08      REM33           NaN
# freq              92      714       5428           NaN
# mean             NaN      NaN        NaN      2.922086
# std              NaN      NaN        NaN      5.410334
# min              NaN      NaN        NaN      0.000000
# 25%              NaN      NaN        NaN      0.000000
# 50%              NaN      NaN        NaN      1.000000
# 75%              NaN      NaN        NaN      4.000000
# max              NaN      NaN        NaN     92.000000
#
#         Infractions entrainant la mort_CRIME_COUNT  Introduction_CRIME_COUNT  \
# count                                 65688.000000              65688.000000
# unique                                         NaN                       NaN
# top                                            NaN                       NaN
# freq                                           NaN                       NaN
# mean                                      0.002664                  0.836713
# std                                       0.053003                  1.981212
# min                                       0.000000                  0.000000
# 25%                                       0.000000                  0.000000
# 50%                                       0.000000                  0.000000
# 75%                                       0.000000                  1.000000
# max                                       3.000000                 34.000000
#
#         Méfait_CRIME_COUNT  Vol dans / sur véhicule à moteur_CRIME_COUNT  \
# count         65688.000000                                  65688.000000
# unique                 NaN                                           NaN
# top                    NaN                                           NaN
# freq                   NaN                                           NaN
# mean              0.638945                                      0.776869
# std               1.527666                                      1.915722
# min               0.000000                                      0.000000
# 25%               0.000000                                      0.000000
# 50%               0.000000                                      0.000000
# 75%               1.000000                                      1.000000
# max              47.000000                                     46.000000
#
#         Vol de véhicule à moteur_CRIME_COUNT  Vols qualifiés_CRIME_COUNT  ...  \
# count                           65688.000000                65688.000000  ...
# unique                                   NaN                         NaN  ...
# top                                      NaN                         NaN  ...
# freq                                     NaN                         NaN  ...
# mean                                0.513184                    0.153711  ...
# std                                 1.148182                    0.552054  ...
# min                                 0.000000                    0.000000  ...
# 25%                                 0.000000                    0.000000  ...
# 50%                                 0.000000                    0.000000  ...
# 75%                                 1.000000                    0.000000  ...
# max                                40.000000                   11.000000  ...
#
#         TEMPERATURE_QUATERLY_MEAN  RAIN_QUATERLY_TOTAL  SNOW_QUATERLY_TOTAL  \
# count                65688.000000         6.568800e+04         6.568800e+04
# unique                        NaN                  NaN                  NaN
# top                           NaN                  NaN                  NaN
# freq                          NaN                  NaN                  NaN
# mean                     7.008295         1.056695e+01         1.814051e+00
# std                      9.069491         5.653440e+00         2.160367e+00
# min                    -13.596285        -1.421085e-14        -1.931788e-13
# 25%                     -1.695450         6.846618e+00         2.100000e-02
# 50%                      7.464216         9.989570e+00         1.141904e+00
# 75%                     16.224446         1.317656e+01         3.089484e+00
# max                     25.437500         7.378065e+01         2.947000e+01
#
#         WINDSPEED_QUATERLY_MEAN  WINDGUSTS_QUATERLY_MEAN  \
# count              65688.000000             65688.000000
# unique                      NaN                      NaN
# top                         NaN                      NaN
# freq                        NaN                      NaN
# mean                  17.186840                37.772828
# std                    1.528647                 2.988427
# min                    9.712500                21.437500
# 25%                   16.126478                35.986434
# 50%                   17.180753                37.569896
# 75%                   18.157613                39.373262
# max                   29.550000                61.637903
#
#         FIRE_RISK_MONTHLY_RANK  FIRE_RISK_QUATERLY_RANK  \
# count             65688.000000             65688.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                 20.459399                47.296569
# std                   3.823499                11.158934
# min                   1.000000                 1.000000
# 25%                  19.000000                43.000000
# 50%                  21.000000                50.000000
# 75%                  23.000000                54.000000
# max                  29.000000                65.000000
#
#         FIRE_COMBINED_RISK_RANK        FIRE_RISK  \
# count              65688.000000            65688
# unique                      NaN                3
# top                         NaN  2-Low Fire-Risk
# freq                        NaN            52688
# mean                  28.953340              NaN
# std                    8.386024              NaN
# min                    1.000000              NaN
# 25%                   24.000000              NaN
# 50%                   30.000000              NaN
# 75%                   35.000000              NaN
# max                   50.000000              NaN
#
#         FIRE_RISK_1_MONTH_FORWARD_SHIFT
# count                             65688
# unique                                3
# top                     2-Low Fire-Risk
# freq                              53110
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
# [11 rows x 82 columns]

# %%
df_last_month = pd.read_csv(
    'Data/Processed_Datasets/Combined_tables/df_fe_combined_last_month.csv', index_col=0)

# Sort dataframe according to month and grid ID
df_last_month.sort_values(['MONTH', '1000_GRID_ID'])

# Reset the index without adding an index column
df_last_month.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65688 entries, 0 to 65687
# Data columns (total 82 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   1000_GRID_ID                                                         65688 non-null  object
#  1   MONTH                                                                65688 non-null  object
#  2   CODEMAMROT                                                           65688 non-null  object
#  3   CRIME_COUNT                                                          65688 non-null  float64
#  4   Infractions entrainant la mort_CRIME_COUNT                           65688 non-null  float64
#  5   Introduction_CRIME_COUNT                                             65688 non-null  float64
#  6   Méfait_CRIME_COUNT                                                   65688 non-null  float64
#  7   Vol dans / sur véhicule à moteur_CRIME_COUNT                         65688 non-null  float64
#  8   Vol de véhicule à moteur_CRIME_COUNT                                 65688 non-null  float64
#  9   Vols qualifiés_CRIME_COUNT                                           65688 non-null  float64
#  10  INCIDENT_COUNT                                                       65688 non-null  float64
#  11  1-REPOND_INCIDENT_COUNT                                              65688 non-null  float64
#  12  AUTREFEU_INCIDENT_COUNT                                              65688 non-null  float64
#  13  Alarmes-incendies_INCIDENT_COUNT                                     65688 non-null  float64
#  14  FAU-ALER_INCIDENT_COUNT                                              65688 non-null  float64
#  15  INCENDIE_INCIDENT_COUNT                                              65688 non-null  float64
#  16  NOUVEAU_INCIDENT_COUNT                                               65688 non-null  float64
#  17  SANS FEU_INCIDENT_COUNT                                              65688 non-null  float64
#  18  FIRE_INCIDENT_COUNT                                                  65688 non-null  float64
#  19  UNIQUE_FIRE_STATION_COUNT                                            65688 non-null  float64
#  20  UNIQUE_DIVISION_COUNT                                                65688 non-null  float64
#  21  UNITS_DEPLOYED_SUM                                                   65688 non-null  float64
#  22  UNITS_DEPLOYED_MEAN                                                  65688 non-null  float64
#  23  temperature_2m_max (°C)_MEAN                                         65688 non-null  float64
#  24  temperature_2m_min (°C)_MEAN                                         65688 non-null  float64
#  25  temperature_2m_mean (°C)_MEAN                                        65688 non-null  float64
#  26  shortwave_radiation_sum (MJ/m²)_MEAN                                 65688 non-null  float64
#  27  precipitation_sum (mm)_MEAN                                          65688 non-null  float64
#  28  rain_sum (mm)_MEAN                                                   65688 non-null  float64
#  29  snowfall_sum (cm)_MEAN                                               65688 non-null  float64
#  30  windspeed_10m_max (km/h)_MEAN                                        65688 non-null  float64
#  31  windgusts_10m_max (km/h)_MEAN                                        65688 non-null  float64
#  32  winddirection_10m_dominant (°)_MEAN                                  65688 non-null  float64
#  33  et0_fao_evapotranspiration (mm)_MEAN                                 65688 non-null  float64
#  34  PROPERTY_ASSESSMENT_COUNT                                            65688 non-null  int64
#  35  Condominium_PROPERTY_ASSESSMENT_COUNT                                65688 non-null  float64
#  36  Régulier_PROPERTY_ASSESSMENT_COUNT                                   65688 non-null  float64
#  37  HEIGHT_ABOVE_GROUND_MEAN                                             65688 non-null  float64
#  38  DWELLING_MEAN                                                        65688 non-null  float64
#  39  CONSTRUCTION_YEAR_MEAN                                               65688 non-null  float64
#  40  LAND_AREA_MEAN                                                       65688 non-null  float64
#  41  BUILDING_AREA_MEAN                                                   65688 non-null  float64
#  42  YEAR                                                                 65688 non-null  int64
#  43  POPULATION_SUM                                                       65688 non-null  float64
#  44  AIRE                                                                 65688 non-null  float64
#  45  POPULATION_DENSITY                                                   65688 non-null  float64
#  46  CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                                   65688 non-null  float64
#  47  Infractions entrainant la mort_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT    65688 non-null  float64
#  48  Introduction_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                      65688 non-null  float64
#  49  Méfait_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                            65688 non-null  float64
#  50  Vol dans / sur véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT  65688 non-null  float64
#  51  Vol de véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT          65688 non-null  float64
#  52  Vols qualifiés_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                    65688 non-null  float64
#  53  INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                                65688 non-null  float64
#  54  1-REPOND_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  55  AUTREFEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  56  Alarmes-incendies_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT              65688 non-null  float64
#  57  FAU-ALER_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  58  INCENDIE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  59  NOUVEAU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                        65688 non-null  float64
#  60  SANS FEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  61  FIRE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                           65688 non-null  float64
#  62  UNIQUE_FIRE_STATION_COUNT_4_MONTH_BACKWARD_SHIFT                     65688 non-null  float64
#  63  UNIQUE_DIVISION_COUNT_4_MONTH_BACKWARD_SHIFT                         65688 non-null  float64
#  64  UNITS_DEPLOYED_SUM_4_MONTH_BACKWARD_SHIFT                            65688 non-null  float64
#  65  UNITS_DEPLOYED_MEAN_4_MONTH_BACKWARD_SHIFT                           65688 non-null  float64
#  66  FIRE_INCIDENT_QUATERLY_MEAN                                          65688 non-null  float64
#  67  FIRE_INCIDENT_QUATERLY_TOTAL                                         65688 non-null  float64
#  68  FIRE_INCIDENT_QUATERLY_MAX                                           65688 non-null  float64
#  69  CRIME_COUNT_QUATERLY_TOTAL                                           65688 non-null  float64
#  70  INCIDENT_COUNT_QUATERLY_TOTAL                                        65688 non-null  float64
#  71  UNITS_DEPLOYED_QUATERLY_TOTAL                                        65688 non-null  float64
#  72  TEMPERATURE_QUATERLY_MEAN                                            65688 non-null  float64
#  73  RAIN_QUATERLY_TOTAL                                                  65688 non-null  float64
#  74  SNOW_QUATERLY_TOTAL                                                  65688 non-null  float64
#  75  WINDSPEED_QUATERLY_MEAN                                              65688 non-null  float64
#  76  WINDGUSTS_QUATERLY_MEAN                                              65688 non-null  float64
#  77  FIRE_RISK_MONTHLY_RANK                                               65688 non-null  float64
#  78  FIRE_RISK_QUATERLY_RANK                                              65688 non-null  float64
#  79  FIRE_COMBINED_RISK_RANK                                              65688 non-null  float64
#  80  FIRE_RISK                                                            65688 non-null  object
#  81  FIRE_RISK_1_MONTH_FORWARD_SHIFT                                      65688 non-null  object
# dtypes: float64(75), int64(2), object(5)
# memory usage: 41.1+ MB

# %%
df.describe(include='all')
# Out:
#         1000_GRID_ID    MONTH CODEMAMROT   CRIME_COUNT  \
# count          65688    65688      65688  65688.000000
# unique           714       92         34           NaN
# top     Fqp0-LorCOE=  2016-08      REM33           NaN
# freq              92      714       5428           NaN
# mean             NaN      NaN        NaN      2.922086
# std              NaN      NaN        NaN      5.410334
# min              NaN      NaN        NaN      0.000000
# 25%              NaN      NaN        NaN      0.000000
# 50%              NaN      NaN        NaN      1.000000
# 75%              NaN      NaN        NaN      4.000000
# max              NaN      NaN        NaN     92.000000
#
#         Infractions entrainant la mort_CRIME_COUNT  Introduction_CRIME_COUNT  \
# count                                 65688.000000              65688.000000
# unique                                         NaN                       NaN
# top                                            NaN                       NaN
# freq                                           NaN                       NaN
# mean                                      0.002664                  0.836713
# std                                       0.053003                  1.981212
# min                                       0.000000                  0.000000
# 25%                                       0.000000                  0.000000
# 50%                                       0.000000                  0.000000
# 75%                                       0.000000                  1.000000
# max                                       3.000000                 34.000000
#
#         Méfait_CRIME_COUNT  Vol dans / sur véhicule à moteur_CRIME_COUNT  \
# count         65688.000000                                  65688.000000
# unique                 NaN                                           NaN
# top                    NaN                                           NaN
# freq                   NaN                                           NaN
# mean              0.638945                                      0.776869
# std               1.527666                                      1.915722
# min               0.000000                                      0.000000
# 25%               0.000000                                      0.000000
# 50%               0.000000                                      0.000000
# 75%               1.000000                                      1.000000
# max              47.000000                                     46.000000
#
#         Vol de véhicule à moteur_CRIME_COUNT  Vols qualifiés_CRIME_COUNT  ...  \
# count                           65688.000000                65688.000000  ...
# unique                                   NaN                         NaN  ...
# top                                      NaN                         NaN  ...
# freq                                     NaN                         NaN  ...
# mean                                0.513184                    0.153711  ...
# std                                 1.148182                    0.552054  ...
# min                                 0.000000                    0.000000  ...
# 25%                                 0.000000                    0.000000  ...
# 50%                                 0.000000                    0.000000  ...
# 75%                                 1.000000                    0.000000  ...
# max                                40.000000                   11.000000  ...
#
#         TEMPERATURE_QUATERLY_MEAN  RAIN_QUATERLY_TOTAL  SNOW_QUATERLY_TOTAL  \
# count                65688.000000         6.568800e+04         6.568800e+04
# unique                        NaN                  NaN                  NaN
# top                           NaN                  NaN                  NaN
# freq                          NaN                  NaN                  NaN
# mean                     7.008295         1.056695e+01         1.814051e+00
# std                      9.069491         5.653440e+00         2.160367e+00
# min                    -13.596285        -1.421085e-14        -1.931788e-13
# 25%                     -1.695450         6.846618e+00         2.100000e-02
# 50%                      7.464216         9.989570e+00         1.141904e+00
# 75%                     16.224446         1.317656e+01         3.089484e+00
# max                     25.437500         7.378065e+01         2.947000e+01
#
#         WINDSPEED_QUATERLY_MEAN  WINDGUSTS_QUATERLY_MEAN  \
# count              65688.000000             65688.000000
# unique                      NaN                      NaN
# top                         NaN                      NaN
# freq                        NaN                      NaN
# mean                  17.186840                37.772828
# std                    1.528647                 2.988427
# min                    9.712500                21.437500
# 25%                   16.126478                35.986434
# 50%                   17.180753                37.569896
# 75%                   18.157613                39.373262
# max                   29.550000                61.637903
#
#         FIRE_RISK_MONTHLY_RANK  FIRE_RISK_QUATERLY_RANK  \
# count             65688.000000             65688.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                 20.459399                47.296569
# std                   3.823499                11.158934
# min                   1.000000                 1.000000
# 25%                  19.000000                43.000000
# 50%                  21.000000                50.000000
# 75%                  23.000000                54.000000
# max                  29.000000                65.000000
#
#         FIRE_COMBINED_RISK_RANK        FIRE_RISK  \
# count              65688.000000            65688
# unique                      NaN                3
# top                         NaN  2-Low Fire-Risk
# freq                        NaN            52688
# mean                  28.953340              NaN
# std                    8.386024              NaN
# min                    1.000000              NaN
# 25%                   24.000000              NaN
# 50%                   30.000000              NaN
# 75%                   35.000000              NaN
# max                   50.000000              NaN
#
#         FIRE_RISK_1_MONTH_FORWARD_SHIFT
# count                             65688
# unique                                3
# top                     2-Low Fire-Risk
# freq                              53110
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
# [11 rows x 82 columns]

# %%
df.tail()
# Out:
#        1000_GRID_ID    MONTH CODEMAMROT  CRIME_COUNT  \
# 65683  zzht2gM06A0=  2022-08      REM17          0.0
# 65684  zzht2gM06A0=  2022-09      REM17          0.0
# 65685  zzht2gM06A0=  2022-10      REM17          0.0
# 65686  zzht2gM06A0=  2022-11      REM17          0.0
# 65687  zzht2gM06A0=  2022-12      REM17          0.0
#
#        Infractions entrainant la mort_CRIME_COUNT  Introduction_CRIME_COUNT  \
# 65683                                         0.0                       0.0
# 65684                                         0.0                       0.0
# 65685                                         0.0                       0.0
# 65686                                         0.0                       0.0
# 65687                                         0.0                       0.0
#
#        Méfait_CRIME_COUNT  Vol dans / sur véhicule à moteur_CRIME_COUNT  \
# 65683                 0.0                                           0.0
# 65684                 0.0                                           0.0
# 65685                 0.0                                           0.0
# 65686                 0.0                                           0.0
# 65687                 0.0                                           0.0
#
#        Vol de véhicule à moteur_CRIME_COUNT  Vols qualifiés_CRIME_COUNT  ...  \
# 65683                                   0.0                         0.0  ...
# 65684                                   0.0                         0.0  ...
# 65685                                   0.0                         0.0  ...
# 65686                                   0.0                         0.0  ...
# 65687                                   0.0                         0.0  ...
#
#        TEMPERATURE_QUATERLY_MEAN  RAIN_QUATERLY_TOTAL  SNOW_QUATERLY_TOTAL  \
# 65683                  18.862500             5.400000        -1.906253e-13
# 65684                  18.332500             5.726667        -1.906253e-13
# 65685                  16.132500             3.176667        -1.906253e-13
# 65686                  11.966667             5.403333         3.873333e-01
# 65687                   5.808602             7.727527         1.498301e+00
#
#        WINDSPEED_QUATERLY_MEAN  WINDGUSTS_QUATERLY_MEAN  \
# 65683                17.462500                39.487500
# 65684                17.299167                38.019167
# 65685                15.899167                33.794167
# 65686                15.443333                32.238333
# 65687                16.676398                34.258898
#
#        FIRE_RISK_MONTHLY_RANK  FIRE_RISK_QUATERLY_RANK  \
# 65683                    23.0                     61.0
# 65684                    25.0                     57.0
# 65685                    24.0                     61.0
# 65686                    24.0                     59.0
# 65687                    21.0                     59.0
#
#        FIRE_COMBINED_RISK_RANK        FIRE_RISK  \
# 65683                     35.0  2-Low Fire-Risk
# 65684                     27.0  2-Low Fire-Risk
# 65685                     32.0  2-Low Fire-Risk
# 65686                     30.0  2-Low Fire-Risk
# 65687                     39.0  2-Low Fire-Risk
#
#        FIRE_RISK_1_MONTH_FORWARD_SHIFT
# 65683                  2-Low Fire-Risk
# 65684                  2-Low Fire-Risk
# 65685                  2-Low Fire-Risk
# 65686                  2-Low Fire-Risk
# 65687                  2-Low Fire-Risk
#
# [5 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['1000_GRID_ID', 'MONTH', 'CODEMAMROT', 'CRIME_COUNT',
#        'Infractions entrainant la mort_CRIME_COUNT',
#        'Introduction_CRIME_COUNT', 'Méfait_CRIME_COUNT',
#        'Vol dans / sur véhicule à moteur_CRIME_COUNT',
#        'Vol de véhicule à moteur_CRIME_COUNT', 'Vols qualifiés_CRIME_COUNT',
#        'INCIDENT_COUNT', '1-REPOND_INCIDENT_COUNT', 'AUTREFEU_INCIDENT_COUNT',
#        'Alarmes-incendies_INCIDENT_COUNT', 'FAU-ALER_INCIDENT_COUNT',
#        'INCENDIE_INCIDENT_COUNT', 'NOUVEAU_INCIDENT_COUNT',
#        'SANS FEU_INCIDENT_COUNT', 'FIRE_INCIDENT_COUNT',
#        'UNIQUE_FIRE_STATION_COUNT', 'UNIQUE_DIVISION_COUNT',
#        'UNITS_DEPLOYED_SUM', 'UNITS_DEPLOYED_MEAN',
#        'temperature_2m_max (°C)_MEAN', 'temperature_2m_min (°C)_MEAN',
#        'temperature_2m_mean (°C)_MEAN', 'shortwave_radiation_sum (MJ/m²)_MEAN',
#        'precipitation_sum (mm)_MEAN', 'rain_sum (mm)_MEAN',
#        'snowfall_sum (cm)_MEAN', 'windspeed_10m_max (km/h)_MEAN',
#        'windgusts_10m_max (km/h)_MEAN', 'winddirection_10m_dominant (°)_MEAN',
#        'et0_fao_evapotranspiration (mm)_MEAN', 'PROPERTY_ASSESSMENT_COUNT',
#        'Condominium_PROPERTY_ASSESSMENT_COUNT',
#        'Régulier_PROPERTY_ASSESSMENT_COUNT', 'HEIGHT_ABOVE_GROUND_MEAN',
#        'DWELLING_MEAN', 'CONSTRUCTION_YEAR_MEAN', 'LAND_AREA_MEAN',
#        'BUILDING_AREA_MEAN', 'YEAR', 'POPULATION_SUM', 'AIRE',
#        'POPULATION_DENSITY', 'CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Infractions entrainant la mort_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Introduction_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Méfait_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Vol dans / sur véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Vol de véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Vols qualifiés_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        '1-REPOND_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'AUTREFEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'Alarmes-incendies_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'FAU-ALER_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'INCENDIE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'NOUVEAU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'SANS FEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'FIRE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'UNIQUE_FIRE_STATION_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'UNIQUE_DIVISION_COUNT_4_MONTH_BACKWARD_SHIFT',
#        'UNITS_DEPLOYED_SUM_4_MONTH_BACKWARD_SHIFT',
#        'UNITS_DEPLOYED_MEAN_4_MONTH_BACKWARD_SHIFT',
#        'FIRE_INCIDENT_QUATERLY_MEAN', 'FIRE_INCIDENT_QUATERLY_TOTAL',
#        'FIRE_INCIDENT_QUATERLY_MAX', 'CRIME_COUNT_QUATERLY_TOTAL',
#        'INCIDENT_COUNT_QUATERLY_TOTAL', 'UNITS_DEPLOYED_QUATERLY_TOTAL',
#        'TEMPERATURE_QUATERLY_MEAN', 'RAIN_QUATERLY_TOTAL',
#        'SNOW_QUATERLY_TOTAL', 'WINDSPEED_QUATERLY_MEAN',
#        'WINDGUSTS_QUATERLY_MEAN', 'FIRE_RISK_MONTHLY_RANK',
#        'FIRE_RISK_QUATERLY_RANK', 'FIRE_COMBINED_RISK_RANK', 'FIRE_RISK',
#        'FIRE_RISK_1_MONTH_FORWARD_SHIFT'],
#       dtype='object')

# %% [markdown]
# ## Drop unecessary columns

# %%
df.drop(columns=['CODEMAMROT', 'CRIME_COUNT', 'YEAR',
                 'Infractions entrainant la mort_CRIME_COUNT',
                 'Introduction_CRIME_COUNT', 'Méfait_CRIME_COUNT',
                 'Vol dans / sur véhicule à moteur_CRIME_COUNT',
                 'Vol de véhicule à moteur_CRIME_COUNT', 'Vols qualifiés_CRIME_COUNT',
                 'INCIDENT_COUNT', '1-REPOND_INCIDENT_COUNT', 'AUTREFEU_INCIDENT_COUNT',
                 'Alarmes-incendies_INCIDENT_COUNT', 'FAU-ALER_INCIDENT_COUNT',
                 'INCENDIE_INCIDENT_COUNT', 'NOUVEAU_INCIDENT_COUNT',
                 'SANS FEU_INCIDENT_COUNT', 'FIRE_INCIDENT_COUNT',
                 'UNIQUE_FIRE_STATION_COUNT', 'UNIQUE_DIVISION_COUNT',
                 'UNITS_DEPLOYED_SUM', 'UNITS_DEPLOYED_MEAN', 'AIRE',
                 'FIRE_INCIDENT_QUATERLY_MEAN', 'FIRE_RISK_MONTHLY_RANK',
                 'FIRE_RISK_QUATERLY_RANK', 'FIRE_COMBINED_RISK_RANK', 'FIRE_RISK'], inplace=True)

# %%
df_last_month.drop(columns=['CODEMAMROT', 'CRIME_COUNT', 'YEAR',
                        'Infractions entrainant la mort_CRIME_COUNT',
                        'Introduction_CRIME_COUNT', 'Méfait_CRIME_COUNT',
                        'Vol dans / sur véhicule à moteur_CRIME_COUNT',
                        'Vol de véhicule à moteur_CRIME_COUNT', 'Vols qualifiés_CRIME_COUNT',
                        'INCIDENT_COUNT', '1-REPOND_INCIDENT_COUNT', 'AUTREFEU_INCIDENT_COUNT',
                        'Alarmes-incendies_INCIDENT_COUNT', 'FAU-ALER_INCIDENT_COUNT',
                        'INCENDIE_INCIDENT_COUNT', 'NOUVEAU_INCIDENT_COUNT',
                        'SANS FEU_INCIDENT_COUNT', 'FIRE_INCIDENT_COUNT',
                        'UNIQUE_FIRE_STATION_COUNT', 'UNIQUE_DIVISION_COUNT',
                        'UNITS_DEPLOYED_SUM', 'UNITS_DEPLOYED_MEAN', 'AIRE',
                        'FIRE_INCIDENT_QUATERLY_MEAN', 'FIRE_RISK_MONTHLY_RANK',
                        'FIRE_RISK_QUATERLY_RANK', 'FIRE_COMBINED_RISK_RANK', 'FIRE_RISK'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65688 entries, 0 to 65687
# Data columns (total 54 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   1000_GRID_ID                                                         65688 non-null  object
#  1   MONTH                                                                65688 non-null  object
#  2   temperature_2m_max (°C)_MEAN                                         65688 non-null  float64
#  3   temperature_2m_min (°C)_MEAN                                         65688 non-null  float64
#  4   temperature_2m_mean (°C)_MEAN                                        65688 non-null  float64
#  5   shortwave_radiation_sum (MJ/m²)_MEAN                                 65688 non-null  float64
#  6   precipitation_sum (mm)_MEAN                                          65688 non-null  float64
#  7   rain_sum (mm)_MEAN                                                   65688 non-null  float64
#  8   snowfall_sum (cm)_MEAN                                               65688 non-null  float64
#  9   windspeed_10m_max (km/h)_MEAN                                        65688 non-null  float64
#  10  windgusts_10m_max (km/h)_MEAN                                        65688 non-null  float64
#  11  winddirection_10m_dominant (°)_MEAN                                  65688 non-null  float64
#  12  et0_fao_evapotranspiration (mm)_MEAN                                 65688 non-null  float64
#  13  PROPERTY_ASSESSMENT_COUNT                                            65688 non-null  int64
#  14  Condominium_PROPERTY_ASSESSMENT_COUNT                                65688 non-null  float64
#  15  Régulier_PROPERTY_ASSESSMENT_COUNT                                   65688 non-null  float64
#  16  HEIGHT_ABOVE_GROUND_MEAN                                             65688 non-null  float64
#  17  DWELLING_MEAN                                                        65688 non-null  float64
#  18  CONSTRUCTION_YEAR_MEAN                                               65688 non-null  float64
#  19  LAND_AREA_MEAN                                                       65688 non-null  float64
#  20  BUILDING_AREA_MEAN                                                   65688 non-null  float64
#  21  POPULATION_SUM                                                       65688 non-null  float64
#  22  POPULATION_DENSITY                                                   65688 non-null  float64
#  23  CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                                   65688 non-null  float64
#  24  Infractions entrainant la mort_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT    65688 non-null  float64
#  25  Introduction_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                      65688 non-null  float64
#  26  Méfait_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                            65688 non-null  float64
#  27  Vol dans / sur véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT  65688 non-null  float64
#  28  Vol de véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT          65688 non-null  float64
#  29  Vols qualifiés_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT                    65688 non-null  float64
#  30  INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                                65688 non-null  float64
#  31  1-REPOND_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  32  AUTREFEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  33  Alarmes-incendies_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT              65688 non-null  float64
#  34  FAU-ALER_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  35  INCENDIE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  36  NOUVEAU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                        65688 non-null  float64
#  37  SANS FEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                       65688 non-null  float64
#  38  FIRE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT                           65688 non-null  float64
#  39  UNIQUE_FIRE_STATION_COUNT_4_MONTH_BACKWARD_SHIFT                     65688 non-null  float64
#  40  UNIQUE_DIVISION_COUNT_4_MONTH_BACKWARD_SHIFT                         65688 non-null  float64
#  41  UNITS_DEPLOYED_SUM_4_MONTH_BACKWARD_SHIFT                            65688 non-null  float64
#  42  UNITS_DEPLOYED_MEAN_4_MONTH_BACKWARD_SHIFT                           65688 non-null  float64
#  43  FIRE_INCIDENT_QUATERLY_TOTAL                                         65688 non-null  float64
#  44  FIRE_INCIDENT_QUATERLY_MAX                                           65688 non-null  float64
#  45  CRIME_COUNT_QUATERLY_TOTAL                                           65688 non-null  float64
#  46  INCIDENT_COUNT_QUATERLY_TOTAL                                        65688 non-null  float64
#  47  UNITS_DEPLOYED_QUATERLY_TOTAL                                        65688 non-null  float64
#  48  TEMPERATURE_QUATERLY_MEAN                                            65688 non-null  float64
#  49  RAIN_QUATERLY_TOTAL                                                  65688 non-null  float64
#  50  SNOW_QUATERLY_TOTAL                                                  65688 non-null  float64
#  51  WINDSPEED_QUATERLY_MEAN                                              65688 non-null  float64
#  52  WINDGUSTS_QUATERLY_MEAN                                              65688 non-null  float64
#  53  FIRE_RISK_1_MONTH_FORWARD_SHIFT                                      65688 non-null  object
# dtypes: float64(50), int64(1), object(3)
# memory usage: 27.1+ MB

# %% [markdown]
# ## Label Encoding

# %%
le = LabelEncoder()
df['FIRE_RISK_1_MONTH_FORWARD_SHIFT'] = le.fit_transform(
    df['FIRE_RISK_1_MONTH_FORWARD_SHIFT'])

# %%
mapping_target_classes = dict(zip(le.classes_, range(len(le.classes_))))

# %%
print(mapping_target_classes)
# Out:
# {'0-High Fire-Risk': 0, '1-Medium Fire-Risk': 1, '2-Low Fire-Risk': 2}

# %%
df.describe(include='all')
# Out:
#         1000_GRID_ID    MONTH  temperature_2m_max (°C)_MEAN  \
# count          65688    65688                  65688.000000
# unique           714       92                           NaN
# top     Fqp0-LorCOE=  2016-08                           NaN
# freq              92      714                           NaN
# mean             NaN      NaN                     11.327581
# std              NaN      NaN                     11.153119
# min              NaN      NaN                    -21.400000
# 25%              NaN      NaN                      0.846711
# 50%              NaN      NaN                     12.166667
# 75%              NaN      NaN                     21.856899
# max              NaN      NaN                     33.800000
#
#         temperature_2m_min (°C)_MEAN  temperature_2m_mean (°C)_MEAN  \
# count                   65688.000000                   65688.000000
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                        2.723442                       7.071079
# std                        11.106126                      11.017013
# min                       -31.400000                     -25.400000
# 25%                        -6.974194                      -2.700000
# 50%                         4.155159                       8.000000
# 75%                        13.102312                      17.426667
# max                        22.500000                      27.900000
#
#         shortwave_radiation_sum (MJ/m²)_MEAN  precipitation_sum (mm)_MEAN  \
# count                           65688.000000                 65688.000000
# unique                                   NaN                          NaN
# top                                      NaN                          NaN
# freq                                     NaN                          NaN
# mean                               13.507968                     3.283813
# std                                 6.645252                     2.759013
# min                                 0.460000                     0.000000
# 25%                                 6.930000                     1.733333
# 50%                                13.666258                     2.959175
# 75%                                19.296667                     4.092700
# max                                31.740000                    64.800000
#
#         rain_sum (mm)_MEAN  snowfall_sum (cm)_MEAN  \
# count         65688.000000            65688.000000
# unique                 NaN                     NaN
# top                    NaN                     NaN
# freq                   NaN                     NaN
# mean              2.661760                0.456079
# std               2.697419                0.860901
# min               0.000000                0.000000
# 25%               1.016667                0.000000
# 50%               2.226667                0.000000
# 75%               3.587625                0.688333
# max              64.800000               23.030000
#
#         windspeed_10m_max (km/h)_MEAN  ...  FIRE_INCIDENT_QUATERLY_MAX  \
# count                    65688.000000  ...                65688.000000
# unique                            NaN  ...                         NaN
# top                               NaN  ...                         NaN
# freq                              NaN  ...                         NaN
# mean                        17.170002  ...                    3.304059
# std                          2.815909  ...                    4.636799
# min                          5.500000  ...                    0.000000
# 25%                         15.335929  ...                    0.000000
# 50%                         17.054839  ...                    2.000000
# 75%                         18.653333  ...                    5.000000
# max                         45.300000  ...                   56.000000
#
#         CRIME_COUNT_QUATERLY_TOTAL  INCIDENT_COUNT_QUATERLY_TOTAL  \
# count                 65688.000000                   65688.000000
# unique                         NaN                            NaN
# top                            NaN                            NaN
# freq                           NaN                            NaN
# mean                     11.694313                      52.006485
# std                      20.286774                      78.881452
# min                       0.000000                       0.000000
# 25%                       0.000000                       1.000000
# 50%                       4.000000                      20.000000
# 75%                      15.000000                      74.000000
# max                     313.000000                     922.000000
#
#         UNITS_DEPLOYED_QUATERLY_TOTAL  TEMPERATURE_QUATERLY_MEAN  \
# count                    65688.000000               65688.000000
# unique                            NaN                        NaN
# top                               NaN                        NaN
# freq                              NaN                        NaN
# mean                        93.876355                   7.008295
# std                        144.318358                   9.069491
# min                          0.000000                 -13.596285
# 25%                          1.000000                  -1.695450
# 50%                         39.000000                   7.464216
# 75%                        131.000000                  16.224446
# max                       1832.000000                  25.437500
#
#         RAIN_QUATERLY_TOTAL  SNOW_QUATERLY_TOTAL  WINDSPEED_QUATERLY_MEAN  \
# count          6.568800e+04         6.568800e+04             65688.000000
# unique                  NaN                  NaN                      NaN
# top                     NaN                  NaN                      NaN
# freq                    NaN                  NaN                      NaN
# mean           1.056695e+01         1.814051e+00                17.186840
# std            5.653440e+00         2.160367e+00                 1.528647
# min           -1.421085e-14        -1.931788e-13                 9.712500
# 25%            6.846618e+00         2.100000e-02                16.126478
# 50%            9.989570e+00         1.141904e+00                17.180753
# 75%            1.317656e+01         3.089484e+00                18.157613
# max            7.378065e+01         2.947000e+01                29.550000
#
#         WINDGUSTS_QUATERLY_MEAN  FIRE_RISK_1_MONTH_FORWARD_SHIFT
# count              65688.000000                     65688.000000
# unique                      NaN                              NaN
# top                         NaN                              NaN
# freq                        NaN                              NaN
# mean                  37.772828                         1.755846
# std                    2.988427                         0.538418
# min                   21.437500                         0.000000
# 25%                   35.986434                         2.000000
# 50%                   37.569896                         2.000000
# 75%                   39.373262                         2.000000
# max                   61.637903                         2.000000
#
# [11 rows x 54 columns]

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Feature filtration method

# %% [markdown]
# In this example, we first perform the ANOVA F-test and chi-squared test as described earlier to select features with p-values less than 0.05. We then perform mutual information feature selection using the mutual_info_classif function from scikit-learn to select features with MI scores greater than 0.05.
#
# Finally, we combine the selected features from all three methods using the set function to create a set of unique features, and then convert the set back to a list. This gives us the final list of selected features that we can use for further analysis or modeling.

# %%
# Split data into target variable and numerical features
target = df['FIRE_RISK_1_MONTH_FORWARD_SHIFT']
numerical_features = df.drop(['1000_GRID_ID', 'MONTH', 'FIRE_RISK_1_MONTH_FORWARD_SHIFT'], axis=1)

# Perform ANOVA F-test
f_scores, p_values = f_oneway(
    *[numerical_features[target == c] for c in target.unique()])
f_scores = pd.Series(f_scores, index=numerical_features.columns)
p_values = pd.Series(p_values, index=numerical_features.columns)

# Select features with p-value less than 0.05
selected_features_f = p_values[p_values < 0.05].index.tolist()

# Perform chi-squared test
chi2_scores = []
p_values = []
for col in numerical_features:
    contingency_table = pd.crosstab(target, numerical_features[col])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_scores.append(chi2)
    p_values.append(p)
chi2_scores = pd.Series(chi2_scores, index=numerical_features.columns)
p_values = pd.Series(p_values, index=numerical_features.columns)

# Select features with p-value less than 0.05
selected_features_chi2 = p_values[p_values < 0.05].index.tolist()

# Perform mutual information feature selection
mi_scores = mutual_info_classif(numerical_features, target)
mi_scores = pd.Series(mi_scores, index=numerical_features.columns)

# Select features with MI score greater than 0.05
selected_features_mi = mi_scores[mi_scores > 0.05].index.tolist()

# Combine selected features from all methods
selected_features = list(set(selected_features_f) | set(
    selected_features_chi2) and set(selected_features_mi))

# %%
print(
    f'Number features selected via ANOVA F-test: {len(selected_features_f)}')
print(
    f'Number features selected via Chi-squared test: {len(selected_features_chi2)}')
print(
    f'Number features selected via Mutual information score: {len(selected_features_mi)}')
# Out:
# Number features selected via ANOVA F-test: 49
# Number features selected via Chi-squared test: 50
# Number features selected via Mutual information score: 43

# %%
print(selected_features)
# Out:
# ['LAND_AREA_MEAN', 'Méfait_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT', 'Introduction_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT', 'TEMPERATURE_QUATERLY_MEAN', 'Condominium_PROPERTY_ASSESSMENT_COUNT', 'WINDSPEED_QUATERLY_MEAN', 'Régulier_PROPERTY_ASSESSMENT_COUNT', '1-REPOND_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT', 'BUILDING_AREA_MEAN', 'precipitation_sum (mm)_MEAN', 'HEIGHT_ABOVE_GROUND_MEAN', 'temperature_2m_mean (°C)_MEAN', 'CRIME_COUNT_4_MONTH_BACKWARD_SHIFT', 'UNITS_DEPLOYED_MEAN_4_MONTH_BACKWARD_SHIFT', 'RAIN_QUATERLY_TOTAL', 'temperature_2m_min (°C)_MEAN', 'rain_sum (mm)_MEAN', 'SNOW_QUATERLY_TOTAL', 'UNIQUE_FIRE_STATION_COUNT_4_MONTH_BACKWARD_SHIFT', 'UNITS_DEPLOYED_QUATERLY_TOTAL', 'WINDGUSTS_QUATERLY_MEAN', 'windspeed_10m_max (km/h)_MEAN', 'winddirection_10m_dominant (°)_MEAN', 'windgusts_10m_max (km/h)_MEAN', 'SANS FEU_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT', 'temperature_2m_max (°C)_MEAN', 'INCIDENT_COUNT_QUATERLY_TOTAL', 'POPULATION_SUM', 'UNITS_DEPLOYED_SUM_4_MONTH_BACKWARD_SHIFT', 'et0_fao_evapotranspiration (mm)_MEAN', 'shortwave_radiation_sum (MJ/m²)_MEAN', 'DWELLING_MEAN', 'FIRE_INCIDENT_QUATERLY_MAX', 'Alarmes-incendies_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT', 'snowfall_sum (cm)_MEAN', 'POPULATION_DENSITY', 'FIRE_INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT', 'CRIME_COUNT_QUATERLY_TOTAL', 'INCIDENT_COUNT_4_MONTH_BACKWARD_SHIFT', 'CONSTRUCTION_YEAR_MEAN', 'Vol dans / sur véhicule à moteur_CRIME_COUNT_4_MONTH_BACKWARD_SHIFT', 'PROPERTY_ASSESSMENT_COUNT', 'FIRE_INCIDENT_QUATERLY_TOTAL']

# %%
selected_features_combined = selected_features + \
    ['1000_GRID_ID', 'MONTH', 'FIRE_RISK_1_MONTH_FORWARD_SHIFT']
selected_features_combined_lm = selected_features + \
    ['1000_GRID_ID', 'MONTH']

# %%
df_final_selected = df[selected_features_combined]
df_final_selected_last_month = df_last_month[selected_features_combined_lm]

# %% [markdown]
# ### Feature correlation analysis

# %%
import seaborn as sns
from scipy.cluster import hierarchy
from sklearn.decomposition import PCA

# %%
df_selected = df[selected_features]
corr_matrix = df_selected.corr()

# create figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Plot correlation matrix as heatmap
sns.heatmap(corr_matrix, cmap='coolwarm')

# add title to heatmap
plt.title('Correlation Matrix of Selected Features', loc='left')

# display the chart
plt.show();

# %%
# File Output
feature_selected_corr_matrix_chart_name = 'feature_selected_corr_matrix.png'
feature_selected_corr_matrix_file_path = 'Data/Data_visualization_folders/feature_engineering/' + \
    feature_selected_corr_matrix_chart_name
if os.path.exists(feature_selected_corr_matrix_chart_name):
    os.remove(feature_selected_corr_matrix_chart_name)
    # Save the plot to a file
    fig.savefig(feature_selected_corr_matrix_file_path,
                dpi=300, bbox_inches='tight')
else:
    # Save the plot to a file
    fig.savefig(feature_selected_corr_matrix_file_path,
                dpi=300, bbox_inches='tight')

# %% [markdown]
# # Output file

# %%
# Output file to folder
file_name = 'df_fe_selected.csv'
if os.path.exists(file_name):
    os.remove(file_name)
df_final_selected.to_csv(
    'Data/Processed_Datasets/Combined_tables/' + file_name)

# %%
# Output file to folder
file_name = 'df_fe_selected_last_month.csv'
if os.path.exists(file_name):
    os.remove(file_name)
df_final_selected_last_month.to_csv(
    'Data/Processed_Datasets/Combined_tables/' + file_name)
